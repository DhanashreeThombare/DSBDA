# %%
import pandas as pd

# %%
import numpy as np

# %%
df=pd.read_csv("C:/Users/HP/Desktop/DSBDA/student.csv")

# %%
df
# Out:
#     gender NationalITy PlaceofBirth       StageID GradeID SectionID  \
# 0        M          KW       KuwaIT    lowerlevel    G-04         A
# 1        M          KW       KuwaIT    lowerlevel    G-04         A
# 2        M          KW       KuwaIT    lowerlevel    G-04         A
# 3        M          KW       KuwaIT    lowerlevel    G-04         A
# 4        M          KW          NaN    lowerlevel    G-04         A
# ..     ...         ...          ...           ...     ...       ...
# 475      F      Jordan       Jordan  MiddleSchool    G-08         A
# 476      F      Jordan       Jordan  MiddleSchool    G-08         A
# 477      F      Jordan       Jordan  MiddleSchool    G-08         A
# 478      F      Jordan       Jordan  MiddleSchool    G-08         A
# 479      F      Jordan       Jordan  MiddleSchool    G-08         A
#
#          Topic Semester Relation  raisedhands  VisITedResources  \
# 0           IT        F   Father         15.0                16
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 480 entries, 0 to 479
# Data columns (total 17 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   gender                    480 non-null    object
#  1   NationalITy               480 non-null    object
#  2   PlaceofBirth              477 non-null    object
#  3   StageID                   480 non-null    object
#  4   GradeID                   480 non-null    object
#  5   SectionID                 480 non-null    object
#  6   Topic                     475 non-null    object
#  7   Semester                  480 non-null    object
#  8   Relation                  480 non-null    object
#  9   raisedhands               475 non-null    float64
#  10  VisITedResources          480 non-null    int64
#  11  AnnouncementsView         480 non-null    int64
#  12  Discussion                480 non-null    int64
# ...

# %%
df.describe()
# Out:
#        raisedhands  VisITedResources  AnnouncementsView  Discussion
# count   475.000000        480.000000         480.000000  480.000000
# mean     46.751579         54.797917          37.918750   43.283333
# std      30.876462         33.080007          26.611244   27.637735
# min       0.000000          0.000000           0.000000    1.000000
# 25%      15.000000         20.000000          14.000000   20.000000
# 50%      50.000000         65.000000          33.000000   39.000000
# 75%      75.000000         84.000000          58.000000   70.000000
# max     100.000000         99.000000          98.000000   99.000000

# %%
df.isnull().sum()
# Out:
# gender                      0
# NationalITy                 0
# PlaceofBirth                3
# StageID                     0
# GradeID                     0
# SectionID                   0
# Topic                       5
# Semester                    0
# Relation                    0
# raisedhands                 5
# VisITedResources            0
# AnnouncementsView           0
# Discussion                  0
# ParentAnsweringSurvey       0
# ParentschoolSatisfaction    0
# StudentAbsenceDays          0
# Class                       0
# dtype: int64

# %%
df['PlaceofBirth']
# Out:
# 0      KuwaIT
# 1      KuwaIT
# 2      KuwaIT
# 3      KuwaIT
# 4         NaN
#         ...
# 475    Jordan
# 476    Jordan
# 477    Jordan
# 478    Jordan
# 479    Jordan
# Name: PlaceofBirth, Length: 480, dtype: object

# %%
modevalue=df['PlaceofBirth'].mode()

# %%
print(modevalue)
# Out:
# 0    KuwaIT
# Name: PlaceofBirth, dtype: object

# %%
df['PlaceofBirth'].replace(np.nan,modevalue)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_1724\3349557698.py in ?()
# ----> 1 df['PlaceofBirth'].replace(np.nan,modevalue)
#
# ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\generic.py in ?(self, to_replace, value, inplace, limit, regex, method)
#    7889                 # dest iterable dict-like
#    7890                 if is_dict_like(value):  # NA -> {'A' : 0, 'B' : -1}
#    7891                     # Operate column-wise
#    7892                     if self.ndim == 1:
# -> 7893                         raise ValueError(
#    7894                             "Series.replace cannot use dict-value and "
#    7895                             "non-None to_replace"
#    7896                         )
#
# ValueError: Series.replace cannot use dict-value and non-None to_replace

# %%
df.columns
# Out:
# Index(['gender', 'NationalITy', 'PlaceofBirth', 'StageID', 'GradeID',
#        'SectionID', 'Topic', 'Semester', 'Relation', 'raisedhands',
#        'VisITedResources', 'AnnouncementsView', 'Discussion',
#        'ParentAnsweringSurvey', 'ParentschoolSatisfaction',
#        'StudentAbsenceDays', 'Class'],
#       dtype='object')

# %%
df.shape
# Out:
# (480, 17)

# %%
df.size
# Out:
# 8160

# %%
df.info
# Out:
# <bound method DataFrame.info of     gender NationalITy PlaceofBirth       StageID GradeID SectionID  \
# 0        M          KW       KuwaIT    lowerlevel    G-04         A
# 1        M          KW       KuwaIT    lowerlevel    G-04         A
# 2        M          KW       KuwaIT    lowerlevel    G-04         A
# 3        M          KW       KuwaIT    lowerlevel    G-04         A
# 4        M          KW          NaN    lowerlevel    G-04         A
# ..     ...         ...          ...           ...     ...       ...
# 475      F      Jordan       Jordan  MiddleSchool    G-08         A
# 476      F      Jordan       Jordan  MiddleSchool    G-08         A
# 477      F      Jordan       Jordan  MiddleSchool    G-08         A
# 478      F      Jordan       Jordan  MiddleSchool    G-08         A
# 479      F      Jordan       Jordan  MiddleSchool    G-08         A
#
#          Topic Semester Relation  raisedhands  VisITedResources  \
# ...

# %%
df.sample(10)
# Out:
#     gender NationalITy PlaceofBirth       StageID GradeID SectionID    Topic  \
# 225      M          KW       KuwaIT  MiddleSchool    G-08         A  Spanish
# 80       M          KW       KuwaIT  MiddleSchool    G-07         A     Math
# 363      M   Palestine       Jordan    lowerlevel    G-02         A   Arabic
# 62       M    venzuela     venzuela    HighSchool    G-10         A       IT
# 288      M   Palestine       Jordan  MiddleSchool    G-06         A  English
# 24       M          KW       KuwaIT  MiddleSchool    G-07         B       IT
# 448      M      Jordan       Jordan  MiddleSchool    G-08         A  History
# 374      M      Jordan       Jordan    lowerlevel    G-02         B   Arabic
# 17       M          KW       KuwaIT  MiddleSchool    G-07         A     Math
# 327      M      Jordan       Jordan    lowerlevel    G-02         A   French
#
#     Semester Relation  raisedhands  VisITedResources  AnnouncementsView  \
# ...

# %%
df.isna()
# Out:
#      gender  NationalITy  PlaceofBirth  StageID  GradeID  SectionID  Topic  \
# 0     False        False         False    False    False      False  False
# 1     False        False         False    False    False      False  False
# 2     False        False         False    False    False      False  False
# 3     False        False         False    False    False      False  False
# 4     False        False          True    False    False      False  False
# ..      ...          ...           ...      ...      ...        ...    ...
# 475   False        False         False    False    False      False  False
# 476   False        False         False    False    False      False  False
# 477   False        False         False    False    False      False  False
# 478   False        False         False    False    False      False  False
# 479   False        False         False    False    False      False  False
#
# ...

# %%
df.dtypes
# Out:
# gender                       object
# NationalITy                  object
# PlaceofBirth                 object
# StageID                      object
# GradeID                      object
# SectionID                    object
# Topic                        object
# Semester                     object
# Relation                     object
# raisedhands                 float64
# VisITedResources              int64
# AnnouncementsView             int64
# Discussion                    int64
# ParentAnsweringSurvey        object
# ParentschoolSatisfaction     object
# StudentAbsenceDays           object
# Class                        object
# dtype: object

# %%
print(modevalue)
# Out:
# 0    KuwaIT
# Name: PlaceofBirth, dtype: object

# %%
df['PlaceofBirth'].fillna(df['PlaceofBirth'].mode()[0],inplace=True)

# %%
df
# Out:
#     gender NationalITy PlaceofBirth       StageID GradeID SectionID  \
# 0        M          KW       KuwaIT    lowerlevel    G-04         A
# 1        M          KW       KuwaIT    lowerlevel    G-04         A
# 2        M          KW       KuwaIT    lowerlevel    G-04         A
# 3        M          KW       KuwaIT    lowerlevel    G-04         A
# 4        M          KW       KuwaIT    lowerlevel    G-04         A
# ..     ...         ...          ...           ...     ...       ...
# 475      F      Jordan       Jordan  MiddleSchool    G-08         A
# 476      F      Jordan       Jordan  MiddleSchool    G-08         A
# 477      F      Jordan       Jordan  MiddleSchool    G-08         A
# 478      F      Jordan       Jordan  MiddleSchool    G-08         A
# 479      F      Jordan       Jordan  MiddleSchool    G-08         A
#
#          Topic Semester Relation  raisedhands  VisITedResources  \
# 0           IT        F   Father         15.0                16
# ...

# %%
df.isnull().sum()
# Out:
# gender                      0
# NationalITy                 0
# PlaceofBirth                0
# StageID                     0
# GradeID                     0
# SectionID                   0
# Topic                       5
# Semester                    0
# Relation                    0
# raisedhands                 5
# VisITedResources            0
# AnnouncementsView           0
# Discussion                  0
# ParentAnsweringSurvey       0
# ParentschoolSatisfaction    0
# StudentAbsenceDays          0
# Class                       0
# dtype: int64

# %%
df['Topic'].isnull().sum()
# Out:
# 5

# %%
md=df['Topic'].mode().iloc[0]
print(md)
df['Topic'].fillna(md,inplace=True)
# Out:
# IT

# %%
# Out:
#     gender NationalITy PlaceofBirth       StageID GradeID SectionID  \
# 0        M          KW       KuwaIT    lowerlevel    G-04         A
# 1        M          KW       KuwaIT    lowerlevel    G-04         A
# 2        M          KW       KuwaIT    lowerlevel    G-04         A
# 3        M          KW       KuwaIT    lowerlevel    G-04         A
# 4        M          KW       KuwaIT    lowerlevel    G-04         A
# ..     ...         ...          ...           ...     ...       ...
# 475      F      Jordan       Jordan  MiddleSchool    G-08         A
# 476      F      Jordan       Jordan  MiddleSchool    G-08         A
# 477      F      Jordan       Jordan  MiddleSchool    G-08         A
# 478      F      Jordan       Jordan  MiddleSchool    G-08         A
# 479      F      Jordan       Jordan  MiddleSchool    G-08         A
#
#          Topic Semester Relation  raisedhands  VisITedResources  \
# 0           IT        F   Father         15.0                16
# ...

# %%
df.isnull().sum()
# Out:
# gender                      0
# NationalITy                 0
# PlaceofBirth                0
# StageID                     0
# GradeID                     0
# SectionID                   0
# Topic                       0
# Semester                    0
# Relation                    0
# raisedhands                 5
# VisITedResources            0
# AnnouncementsView           0
# Discussion                  0
# ParentAnsweringSurvey       0
# ParentschoolSatisfaction    0
# StudentAbsenceDays          0
# Class                       0
# dtype: int64

# %%
df['Topic'].isnull().sum()
# Out:
# 0

# %%
meanv=df['raisedhands'].mean()
print(meanv)
# Out:
# 46.75157894736842

# %%
df['raisedhands'].fillna(meanv,inplace=True)
df['raisedhands'].isnull().sum()
# Out:
# 0

# %%
df.isnull().sum()
# Out:
# gender                      0
# NationalITy                 0
# PlaceofBirth                0
# StageID                     0
# GradeID                     0
# SectionID                   0
# Topic                       0
# Semester                    0
# Relation                    0
# raisedhands                 0
# VisITedResources            0
# AnnouncementsView           0
# Discussion                  0
# ParentAnsweringSurvey       0
# ParentschoolSatisfaction    0
# StudentAbsenceDays          0
# Class                       0
# dtype: int64

# %%
df.dtypes
# Out:
# gender                       object
# NationalITy                  object
# PlaceofBirth                 object
# StageID                      object
# GradeID                      object
# SectionID                    object
# Topic                        object
# Semester                     object
# Relation                     object
# raisedhands                 float64
# VisITedResources              int64
# AnnouncementsView             int64
# Discussion                    int64
# ParentAnsweringSurvey        object
# ParentschoolSatisfaction     object
# StudentAbsenceDays           object
# Class                        object
# dtype: object

# %%
df['raisedhands']
# Out:
# 0      15
# 1      46
# 2      10
# 3      30
# 4      40
#        ..
# 475     5
# 476    50
# 477    55
# 478    30
# 479    35
# Name: raisedhands, Length: 480, dtype: int64

# %%
df['raisedhands']=df['raisedhands'].astype('int64')

# %%
df['raisedhands'].dtypes
# Out:
# dtype('int64')

# %%
df['gender'].replace(['M','F'],[0,1],inplace=True)

# %%
df['gender']
# Out:
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 475    1
# 476    1
# 477    1
# 478    1
# 479    1
# Name: gender, Length: 480, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 480 entries, 0 to 479
# Data columns (total 17 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   gender                    480 non-null    int64
#  1   NationalITy               480 non-null    object
#  2   PlaceofBirth              480 non-null    object
#  3   StageID                   480 non-null    object
#  4   GradeID                   480 non-null    object
#  5   SectionID                 480 non-null    object
#  6   Topic                     480 non-null    object
#  7   Semester                  480 non-null    object
#  8   Relation                  480 non-null    object
#  9   raisedhands               480 non-null    int64
#  10  VisITedResources          480 non-null    int64
#  11  AnnouncementsView         480 non-null    int64
#  12  Discussion                480 non-null    int64
#  13  ParentAnsweringSurvey     480 non-null    object
# ...

# %%
df['Semester']
# Out:
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 475    1
# 476    0
# 477    1
# 478    0
# 479    1
# Name: Semester, Length: 480, dtype: int8

# %%
df['Semester']=df['Semester'].astype('category')
df['Semester']=df['Semester'].cat.codes

# %%
df
# Out:
#      gender NationalITy PlaceofBirth       StageID GradeID SectionID  \
# 0         0          KW       KuwaIT    lowerlevel    G-04         A
# 1         0          KW       KuwaIT    lowerlevel    G-04         A
# 2         0          KW       KuwaIT    lowerlevel    G-04         A
# 3         0          KW       KuwaIT    lowerlevel    G-04         A
# 4         0          KW       KuwaIT    lowerlevel    G-04         A
# ..      ...         ...          ...           ...     ...       ...
# 475       1      Jordan       Jordan  MiddleSchool    G-08         A
# 476       1      Jordan       Jordan  MiddleSchool    G-08         A
# 477       1      Jordan       Jordan  MiddleSchool    G-08         A
# 478       1      Jordan       Jordan  MiddleSchool    G-08         A
# 479       1      Jordan       Jordan  MiddleSchool    G-08         A
#
#          Topic  Semester Relation  raisedhands  VisITedResources  \
# 0           IT         0   Father           15                16
# ...

# %%
df.columns
# Out:
# Index(['gender', 'NationalITy', 'PlaceofBirth', 'StageID', 'GradeID',
#        'SectionID', 'Topic', 'Semester', 'Relation', 'raisedhands',
#        'VisITedResources', 'AnnouncementsView', 'Discussion',
#        'ParentAnsweringSurvey', 'ParentschoolSatisfaction',
#        'StudentAbsenceDays', 'Class'],
#       dtype='object')

# %%
minval=df['Discussion'].min()
maxval=df['Discussion'].max()
df['Discussion']=(df['Discussion']-minval)/(maxval-minval)

# %%
df
# Out:
#      gender NationalITy PlaceofBirth       StageID GradeID SectionID  \
# 0         0          KW       KuwaIT    lowerlevel    G-04         A
# 1         0          KW       KuwaIT    lowerlevel    G-04         A
# 2         0          KW       KuwaIT    lowerlevel    G-04         A
# 3         0          KW       KuwaIT    lowerlevel    G-04         A
# 4         0          KW       KuwaIT    lowerlevel    G-04         A
# ..      ...         ...          ...           ...     ...       ...
# 475       1      Jordan       Jordan  MiddleSchool    G-08         A
# 476       1      Jordan       Jordan  MiddleSchool    G-08         A
# 477       1      Jordan       Jordan  MiddleSchool    G-08         A
# 478       1      Jordan       Jordan  MiddleSchool    G-08         A
# 479       1      Jordan       Jordan  MiddleSchool    G-08         A
#
#          Topic  Semester Relation  raisedhands  VisITedResources  \
# 0           IT         0   Father           15                16
# ...
