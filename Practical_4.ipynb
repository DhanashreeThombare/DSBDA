# %%
import pandas as pd

# %%
df=pd.read_csv("BostonHousing.csv")

# %%
df
# Out:
#         crim    zn  indus  chas    nox     rm   age     dis  rad  tax  \
# 0    0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296
# 1    0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242
# 2    0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242
# 3    0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222
# 4    0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...  ...
# 501  0.06263   0.0  11.93     0  0.573  6.593  69.1  2.4786    1  273
# 502  0.04527   0.0  11.93     0  0.573  6.120  76.7  2.2875    1  273
# 503  0.06076   0.0  11.93     0  0.573  6.976  91.0  2.1675    1  273
# 504  0.10959   0.0  11.93     0  0.573  6.794  89.3  2.3889    1  273
# 505  0.04741   0.0  11.93     0  0.573  6.030  80.8  2.5050    1  273
#
#      ptratio       b  lstat  medv
# 0       15.3  396.90   4.98  24.0
# 1       17.8  396.90   9.14  21.6
# 2       17.8  392.83   4.03  34.7
# 3       18.7  394.63   2.94  33.4
# 4       18.7  396.90   5.33  36.2
# ..       ...     ...    ...   ...
# 501     21.0  391.99   9.67  22.4
# 502     21.0  396.90   9.08  20.6
# 503     21.0  396.90   5.64  23.9
# 504     21.0  393.45   6.48  22.0
# 505     21.0  396.90   7.88  11.9
#
# [506 rows x 14 columns]

# %%
df.isnull().sum()
# Out:
# crim       0
# zn         0
# indus      0
# chas       0
# nox        0
# rm         0
# age        0
# dis        0
# rad        0
# tax        0
# ptratio    0
# b          0
# lstat      0
# medv       0
# dtype: int64

# %%
df.rm=df.rm.fillna(df.rm.mean())

# %%
X=df.drop("medv",axis=1)

# %%
y=df['medv']

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y)

# %%
from sklearn.linear_model import LinearRegression

# %%
lr=LinearRegression()

# %%
lr.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred=lr.predict(X_test)

# %%
y_pred
# Out:
# array([28.02477585, 28.1404089 , 11.20004307, 28.39708705, 13.08571124,
#        31.11813128, 25.80066906, 18.97580045, 19.62139497, 34.29496688,
#        23.38032203, 11.88708153, 17.63679169, 35.21899344, 28.04594157,
#        19.91956573, 21.25512468, 19.97661415, 16.82362245, 20.51731905,
#        21.98259642, 19.30432174, 20.90669869, 35.08204251, 21.96654886,
#        32.02764794, 24.65084352, 14.77254479, 22.49939007, 24.27356293,
#        19.36269385, 16.26533608, 14.55905435, 27.60757893, 20.59038759,
#         3.16775459, 24.23179677, 33.53981852, 26.83658072, 34.10556318,
#        27.15405328,  0.12237388, 44.03318731, 24.63322974, 14.6058162 ,
#        21.80037916, 20.20902599, 11.92186486, 12.71831091, 25.27662372,
#        28.97107493, 19.85331932, 17.03591545, 23.49477709, 24.57760691,
#        41.09433329, 20.23008994, 17.20944281, 24.86133756, 32.45841283,
#        19.5928191 , 38.81202307, 13.41470981, 35.96930789, 40.74555999,
#        27.51028577, 28.80533306, 16.3344693 , 28.40365675, 10.71218068,
#        17.5215713 ,  9.77427732, 16.58047713, 17.19269455, 28.79812471,
#        26.70206044, 22.62553507, 35.48077851, 25.45231486, 19.06973836,
#        17.67460752, 32.70924026, 15.08240117, 15.96794698, 22.17744284,
#        19.24605949, 11.99032515, 19.97481341, 31.8778877 , 18.55044206,
#        25.08644123, 18.50864702, 23.14631708, 24.35748793, 16.22295266,
#        26.68549586, 13.40400509, 23.83262006, 21.34278854, 13.53287659,
#        25.52157326, 17.85227114, 31.24564563, 21.87694337, 20.66006481,
#        27.48144069, 30.18466048, 25.1985245 , 19.04775206, 31.33024413,
#        12.12643361, 14.48265702, 19.91388548, 16.26686248, 31.2462448 ,
#        15.32054526, 18.2960413 , 25.02440559, 14.01353811, 15.5064913 ,
#        18.34773275, 28.03810496, 13.63416041, 21.62900776, 25.57505065,
#        36.95514705, 23.01328871])

# %%
from sklearn.metrics import mean_squared_error,mean_absolute_error,r2_score

# %%
mean_squared_error(y_test,y_pred)
# Out:
# 31.7472887890208

# %%
mean_absolute_error(y_pred,y_test)
# Out:
# 3.683242378006379

# %%
r2_score(y_test,y_pred)
# Out:
# 0.6226504485153567

# %%
from sklearn.preprocessing import StandardScaler

# %%
s=StandardScaler()

# %%
X_train=s.fit_transform(X_train)

# %%
X_test=s.transform(X_test)

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2)

# %%
lr1=LinearRegression()

# %%
lr1.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred=lr1.predict(X_test)

# %%
mean_squared_error(y_test,y_pred)
# Out:
# 25.686794674376742

# %%
mean_absolute_error(y_pred,y_test)
# Out:
# 3.5698695577858994

# %%
r2_score(y_pred,y_test)
# Out:
# 0.6194946888593114

# %%
lr.score(X_train,y_train)
# Out:
# 0.7371326748092085

# %%
lr.score(X_test,y_test)
# Out:
# 0.7351100092858109

# %%
lr1.score(X_train,y_train)
# Out:
# 0.7406365808955749

# %%
lr1.score(X_test,y_test)
# Out:
# 0.7256968251218359
