# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=sns.load_dataset("titanic")

# %%
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
df.isnull().sum()
# Out:
# survived         0
# pclass           0
# sex              0
# age            177
# sibsp            0
# parch            0
# fare             0
# embarked         2
# class            0
# who              0
# adult_male       0
# deck           688
# embark_town      2
# alive            0
# alone            0
# dtype: int64

# %%
df.shape
# Out:
# (891, 15)

# %%
plt.hist(df.fare)
plt.xlabel("Fare")
plt.ylabel("Frequency")
plt.grid(True)
plt.show()

# %%
df['fare']
# Out:
# 0       7.2500
# 1      71.2833
# 2       7.9250
# 3      53.1000
# 4       8.0500
#         ...
# 886    13.0000
# 887    30.0000
# 888    23.4500
# 889    30.0000
# 890     7.7500
# Name: fare, Length: 891, dtype: float64

# %%
plt.figure(figsize=(16,10))
plt.plot(df.index,df.fare)
plt.xlabel("Passanger")
plt.ylabel("Fare")
plt.title("Fare for each passenger")
plt.grid(True)

# %%
plt.figure(figsize=(4,6))
plt.hist(df.sex)
plt.xlabel('gender')
plt.ylabel('freq')
plt.grid(True)

# %%
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
df['embark_town'].fillna('Unknown',inplace=True)

# %%
df['embark_town'].isna().sum()
# Out:
# 0

# %%
plt.pie(
    df['embark_town'].value_counts(),
    labels=df['embark_town'].unique(),
    autopct='%1.1f%%',
    startangle=180
)
plt.show()

# %%
sns.pairplot(df)
plt.show()

# %%
plt.pie(
    df['sex'].value_counts(),startangle=140,labels=df['sex'].unique(),autopct="%1.1f%%"
)
plt.show()

# %%
sns.lineplot(x=df.survived,y=df.fare)
plt.show()

# %%
sns.barplot(x=df['sex'],y=df['age'])
# Out:
# <AxesSubplot:xlabel='sex', ylabel='age'>

# %%
sns.barplot(x=df['sex'],y=df['age'],hue=df['survived'])
# Out:
# <AxesSubplot:xlabel='sex', ylabel='age'>

# %%
#sns.scatterplot(df.age,df.fare)
sns.scatterplot(df.age,df.fare,hue = df.age)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[44], line 2
#       1 #sns.scatterplot(df.age,df.fare)
# ----> 2 sns.scatterplot(df.age,df.fare,hue = df.age)
#
# TypeError: scatterplot() takes from 0 to 1 positional arguments but 2 positional arguments (and 1 keyword-only argument) were given

# %%
sns.boxplot(x=df['sex'],y=df['age'])
# Out:
# <AxesSubplot:xlabel='sex', ylabel='age'>

# %%
sns.barplot(y=df['survived'],x=df['class'])
# Out:
# <AxesSubplot:xlabel='class', ylabel='survived'>

# %%
print("No. of females survived : ")
df[(df['survived']==1) & (df['sex']=='female')].shape[0]
# Out:
# No. og females survived :
# 233

# %%
print("No. of male survived : ")
df[(df['survived']==1) & (df['sex']=='male')].shape[0]
# Out:
# No. of male survived :
# 109

# %%
print("No. of females dead : ")
df[(df['survived']==0) & (df['sex']=='female')].shape[0]
# Out:
# No. of females dead :
# 81

# %%
print("No. of male dead : ")
df[(df['survived']==0) & (df['sex']=='female')].shape[0]
# Out:
# No. of male dead :
# 81

# %%
print("No. of children survived : ")
df[(df['survived']==1) & (df['age'] <15)].shape[0]
# Out:
# No. of children survived :
# 45
