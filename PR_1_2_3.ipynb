# %%
import pandas as pd

# %%
df=pd.read_csv("student.csv")

# %%
df
# Out:
#     gender NationalITy PlaceofBirth       StageID GradeID SectionID  \
# 0        M          KW       KuwaIT    lowerlevel    G-04         A
# 1        M          KW       KuwaIT    lowerlevel    G-04         A
# 2        M          KW       KuwaIT    lowerlevel    G-04         A
# 3        M          KW       KuwaIT    lowerlevel    G-04         A
# 4        M          KW          NaN    lowerlevel    G-04         A
# ..     ...         ...          ...           ...     ...       ...
# 475      F      Jordan       Jordan  MiddleSchool    G-08         A
# 476      F      Jordan       Jordan  MiddleSchool    G-08         A
# 477      F      Jordan       Jordan  MiddleSchool    G-08         A
# 478      F      Jordan       Jordan  MiddleSchool    G-08         A
# 479      F      Jordan       Jordan  MiddleSchool    G-08         A
#
#          Topic Semester Relation  raisedhands  VisITedResources  \
# 0           IT        F   Father         15.0                16
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 480 entries, 0 to 479
# Data columns (total 17 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   gender                    480 non-null    object
#  1   NationalITy               480 non-null    object
#  2   PlaceofBirth              477 non-null    object
#  3   StageID                   480 non-null    object
#  4   GradeID                   480 non-null    object
#  5   SectionID                 480 non-null    object
#  6   Topic                     475 non-null    object
#  7   Semester                  480 non-null    object
#  8   Relation                  480 non-null    object
#  9   raisedhands               475 non-null    float64
#  10  VisITedResources          480 non-null    int64
#  11  AnnouncementsView         480 non-null    int64
#  12  Discussion                480 non-null    int64
# ...

# %%
df.describe()
# Out:
#        raisedhands  VisITedResources  AnnouncementsView  Discussion
# count   475.000000        480.000000         480.000000  480.000000
# mean     46.751579         54.797917          37.918750   43.283333
# std      30.876462         33.080007          26.611244   27.637735
# min       0.000000          0.000000           0.000000    1.000000
# 25%      15.000000         20.000000          14.000000   20.000000
# 50%      50.000000         65.000000          33.000000   39.000000
# 75%      75.000000         84.000000          58.000000   70.000000
# max     100.000000         99.000000          98.000000   99.000000

# %%
df.head()
# Out:
#   gender NationalITy PlaceofBirth     StageID GradeID SectionID Topic  \
# 0      M          KW       KuwaIT  lowerlevel    G-04         A    IT
# 1      M          KW       KuwaIT  lowerlevel    G-04         A    IT
# 2      M          KW       KuwaIT  lowerlevel    G-04         A    IT
# 3      M          KW       KuwaIT  lowerlevel    G-04         A    IT
# 4      M          KW          NaN  lowerlevel    G-04         A    IT
#
#   Semester Relation  raisedhands  VisITedResources  AnnouncementsView  \
# 0        F   Father         15.0                16                  2
# 1        F   Father          NaN                20                  3
# 2        F   Father         10.0                 7                  0
# 3        F   Father         30.0                25                  5
# 4        F   Father         40.0                50                 12
#
#    Discussion ParentAnsweringSurvey ParentschoolSatisfaction  \
# ...

# %%
df.tail()
# Out:
#     gender NationalITy PlaceofBirth       StageID GradeID SectionID  \
# 475      F      Jordan       Jordan  MiddleSchool    G-08         A
# 476      F      Jordan       Jordan  MiddleSchool    G-08         A
# 477      F      Jordan       Jordan  MiddleSchool    G-08         A
# 478      F      Jordan       Jordan  MiddleSchool    G-08         A
# 479      F      Jordan       Jordan  MiddleSchool    G-08         A
#
#          Topic Semester Relation  raisedhands  VisITedResources  \
# 475  Chemistry        S   Father          5.0                 4
# 476    Geology        F   Father         50.0                77
# 477    Geology        S   Father         55.0                74
# 478    History        F   Father         30.0                17
# 479    History        S   Father         35.0                14
#
#      AnnouncementsView  Discussion ParentAnsweringSurvey  \
# 475                  5           8                    No
# ...

# %%
df.isnull().sum()
# Out:
# gender                      0
# NationalITy                 0
# PlaceofBirth                3
# StageID                     0
# GradeID                     0
# SectionID                   0
# Topic                       5
# Semester                    0
# Relation                    0
# raisedhands                 5
# VisITedResources            0
# AnnouncementsView           0
# Discussion                  0
# ParentAnsweringSurvey       0
# ParentschoolSatisfaction    0
# StudentAbsenceDays          0
# Class                       0
# dtype: int64

# %%
df.isnull()
# Out:
#      gender  NationalITy  PlaceofBirth  StageID  GradeID  SectionID  Topic  \
# 0     False        False         False    False    False      False  False
# 1     False        False         False    False    False      False  False
# 2     False        False         False    False    False      False  False
# 3     False        False         False    False    False      False  False
# 4     False        False          True    False    False      False  False
# ..      ...          ...           ...      ...      ...        ...    ...
# 475   False        False         False    False    False      False  False
# 476   False        False         False    False    False      False  False
# 477   False        False         False    False    False      False  False
# 478   False        False         False    False    False      False  False
# 479   False        False         False    False    False      False  False
#
# ...

# %%
df.shape
# Out:
# (480, 17)

# %%
df.columns
# Out:
# Index(['gender', 'NationalITy', 'PlaceofBirth', 'StageID', 'GradeID',
#        'SectionID', 'Topic', 'Semester', 'Relation', 'raisedhands',
#        'VisITedResources', 'AnnouncementsView', 'Discussion',
#        'ParentAnsweringSurvey', 'ParentschoolSatisfaction',
#        'StudentAbsenceDays', 'Class'],
#       dtype='object')

# %%
df.dtypes
# Out:
# gender                       object
# NationalITy                  object
# PlaceofBirth                 object
# StageID                      object
# GradeID                      object
# SectionID                    object
# Topic                        object
# Semester                     object
# Relation                     object
# raisedhands                 float64
# VisITedResources              int64
# AnnouncementsView             int64
# Discussion                    int64
# ParentAnsweringSurvey        object
# ParentschoolSatisfaction     object
# StudentAbsenceDays           object
# Class                        object
# dtype: object

# %%
df.isnull().sum()
# Out:
# gender                        0
# NationalITy                   0
# PlaceofBirth                  3
# StageID                       0
# GradeID                       0
# SectionID                     0
# Topic                       480
# Semester                      0
# Relation                      0
# raisedhands                   5
# VisITedResources              0
# AnnouncementsView             0
# Discussion                    0
# ParentAnsweringSurvey         0
# ParentschoolSatisfaction      0
# StudentAbsenceDays            0
# Class                         0
# dtype: int64

# %%
df=pd.read_csv('student.csv')
#df['Topic'].fillna(df['Topic'].mode()[0],inplace=True)

# %%
df['Topic']
# Out:
# 0             IT
# 1             IT
# 2             IT
# 3             IT
# 4             IT
#          ...
# 475    Chemistry
# 476      Geology
# 477      Geology
# 478      History
# 479      History
# Name: Topic, Length: 480, dtype: object

# %%
modev=df['Topic'].mode().iloc[0]
modev
# Out:
# 'IT'

# %%
df['Topic'].fillna(modev,inplace=True)

# %%
df['Topic'].isna().sum()
# Out:
# 0

# %%
df.isna().sum()
# Out:
# gender                      0
# NationalITy                 0
# PlaceofBirth                0
# StageID                     0
# GradeID                     0
# SectionID                   0
# Topic                       0
# Semester                    0
# Relation                    0
# raisedhands                 0
# VisITedResources            0
# AnnouncementsView           0
# Discussion                  0
# ParentAnsweringSurvey       0
# ParentschoolSatisfaction    0
# StudentAbsenceDays          0
# Class                       0
# dtype: int64

# %%
df['raisedhands'].fillna(df['raisedhands'].mode()[0],inplace=True)

# %%
df['PlaceofBirth'].fillna(df['PlaceofBirth'].mode()[0],inplace=True)

# %%
df.dtypes
# Out:
# gender                       object
# NationalITy                  object
# PlaceofBirth                 object
# StageID                      object
# GradeID                      object
# SectionID                    object
# Topic                        object
# Semester                     object
# Relation                     object
# raisedhands                 float64
# VisITedResources              int64
# AnnouncementsView             int64
# Discussion                    int64
# ParentAnsweringSurvey        object
# ParentschoolSatisfaction     object
# StudentAbsenceDays           object
# Class                        object
# dtype: object

# %%
df['gender'].replace(['M','F'],[0,1],inplace=True)

# %%
df
# Out:
#      gender NationalITy PlaceofBirth       StageID GradeID SectionID  \
# 0         0          KW       KuwaIT    lowerlevel    G-04         A
# 1         0          KW       KuwaIT    lowerlevel    G-04         A
# 2         0          KW       KuwaIT    lowerlevel    G-04         A
# 3         0          KW       KuwaIT    lowerlevel    G-04         A
# 4         0          KW       KuwaIT    lowerlevel    G-04         A
# ..      ...         ...          ...           ...     ...       ...
# 475       1      Jordan       Jordan  MiddleSchool    G-08         A
# 476       1      Jordan       Jordan  MiddleSchool    G-08         A
# 477       1      Jordan       Jordan  MiddleSchool    G-08         A
# 478       1      Jordan       Jordan  MiddleSchool    G-08         A
# 479       1      Jordan       Jordan  MiddleSchool    G-08         A
#
#          Topic Semester Relation  raisedhands  VisITedResources  \
# 0           IT        F   Father         15.0                16
# ...

# %%
df['Topic']=df['Topic'].astype('category')

# %%
df['Topic']=df['Topic'].cat.codes

# %%
df['Topic']
# Out:
# 0      7
# 1      7
# 2      7
# 3      7
# 4      7
#       ..
# 475    2
# 476    5
# 477    5
# 478    6
# 479    6
# Name: Topic, Length: 480, dtype: int8

# %%
minv=df['Discussion'].min()
maxv=df['Discussion'].max()
print(minv,"\t",maxv)
# Out:
# 1 	 99

# %%
df['Discussion']=(df['Discussion']-minv)/(maxv-minv)

# %%
df
# Out:
#      gender NationalITy PlaceofBirth       StageID GradeID SectionID  Topic  \
# 0         0          KW       KuwaIT    lowerlevel    G-04         A      7
# 1         0          KW       KuwaIT    lowerlevel    G-04         A      7
# 2         0          KW       KuwaIT    lowerlevel    G-04         A      7
# 3         0          KW       KuwaIT    lowerlevel    G-04         A      7
# 4         0          KW       KuwaIT    lowerlevel    G-04         A      7
# ..      ...         ...          ...           ...     ...       ...    ...
# 475       1      Jordan       Jordan  MiddleSchool    G-08         A      2
# 476       1      Jordan       Jordan  MiddleSchool    G-08         A      5
# 477       1      Jordan       Jordan  MiddleSchool    G-08         A      5
# 478       1      Jordan       Jordan  MiddleSchool    G-08         A      6
# 479       1      Jordan       Jordan  MiddleSchool    G-08         A      6
#
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt
df=pd.read_csv('data.csv')
df.boxplot()
plt.show()

# %%
sns.boxplot(df['age'])
plt.show()

# %%
q1=df['age'].quantile(0.25)
q3=df['age'].quantile(0.75)

# %%
iqr=q3-q1

# %%
high=q3+1.5*iqr
low=q1-1.5*iqr

print(low,"\t",high)
# Out:
# 10.875 	 29.875

# %%
df1=df[(df['age']<low) | (df['age']>high)]

# %%
df1
# Out:
#     Roll Number First Name Last Name  Mobile Number  CGPA1  CGPA2  age
# 6           532  Vaishnavi       Jha   919009969408   5.63   4.38    2
# 27          722  Vaishnavi     Patel   917550452611   9.49   3.29  180

# %%
df=df[(df['age']>=low )& (df['age']<=high)]

# %%
df
# Out:
#     Roll Number First Name Last Name  Mobile Number  CGPA1  CGPA2  age
# 0           261      Rishi     Gupta   919954629666   9.92   5.06   19
# 1           827      Seema     Singh   919085484267   0.22   2.83   20
# 2           566      Pooja       Rao   919692747629   4.00   5.78   20
# 3           431     Vikram   Trivedi   919289900918   3.93    NaN   20
# 4           688      Rishi      Nair   918510327681   0.34   3.35   22
# 5           401      Pooja      Bose   918752969300   8.74   7.23   19
# 7           774  Vaishnavi     Verma   917407265215   8.35   2.51   23
# 8           942     Nikita     Mehta   917631350107   0.66   0.50   18
# 9           660      Divya      Devi   919595059601    NaN   9.66   24
# 10           32  Vaishnavi    Pandey   918922269173   4.02   4.08   17
# 11          300      Seema   Agarwal   919811084246   3.35   9.33   16
# 12          501      Anika   Agarwal   918906573611   1.66   6.82   19
# ...

# %%
sns.boxplot(df['age'])
plt.show()

# %%
df
# Out:
#     Roll Number First Name Last Name  Mobile Number  CGPA1  CGPA2  age
# 0           261      Rishi     Gupta   919954629666   9.92   5.06   19
# 1           827      Seema     Singh   919085484267   0.22   2.83   20
# 2           566      Pooja       Rao   919692747629   4.00   5.78   20
# 3           431     Vikram   Trivedi   919289900918   3.93    NaN   20
# 4           688      Rishi      Nair   918510327681   0.34   3.35   22
# 5           401      Pooja      Bose   918752969300   8.74   7.23   19
# 7           774  Vaishnavi     Verma   917407265215   8.35   2.51   23
# 8           942     Nikita     Mehta   917631350107   0.66   0.50   18
# 9           660      Divya      Devi   919595059601    NaN   9.66   24
# 10           32  Vaishnavi    Pandey   918922269173   4.02   4.08   17
# 11          300      Seema   Agarwal   919811084246   3.35   9.33   16
# 12          501      Anika   Agarwal   918906573611   1.66   6.82   19
# ...

# %%
df.dtypes
# Out:
# Roll Number         int8
# First Name        object
# Last Name         object
# Mobile Number      int64
# CGPA1            float64
# CGPA2            float64
# age                int64
# dtype: object

# %%
df['Roll Number']=df['Roll Number'].astype('int8')

# %%
df['CGPA2']
# Out:
# 0     5.06
# 1     2.83
# 2     5.78
# 3      NaN
# 4     3.35
# 5     7.23
# 7     2.51
# 8     0.50
# 9     9.66
# 10    4.08
# 11    9.33
# 12    6.82
# 13    1.37
# 14    9.06
# 15    3.61
# 16    1.51
# 17    1.19
# 18    3.13
# 19    2.63
# 20    3.88
# 21    3.72
# 22    4.00
# 23    1.82
# 24     NaN
# 25    9.72
# 26    8.84
# 28    4.33
# 29    7.34
# 30    6.83
# 31    4.69
# 32    1.62
# 33    1.70
# 34    6.43
# 35    0.28
# 36    9.18
# 37    0.25
# 38    3.36
# 39    4.33
# 40    5.75
# 41    5.90
# 42    4.74
# 43     NaN
# 44    4.11
# 45    6.73
# 46    1.57
# 47    9.08
# 48    4.01
# 49    4.02
# Name: CGPA2, dtype: float64

# %%
df['CGPA2'].skew()
# Out:
# 0.36465710144175295

# %%
iqr
# Out:
# 4.75

# %%
import numpy as np
df['CGPA2']=df['CGPA2'].apply(lambda x:np.log(x) if x>0 else 0)

# %%
df['CGPA2'].skew()
# Out:
# -1.1259635142427533

# %%
val=-1.12 < 0.36

# %%
val
# Out:
# True

# %%
sns.histplot(df['CGPA2'],kde=True)
plt.show()

# %%
sns.histplot(df['CGPA1'],kde=True)
plt.show()

# %%
df['CGPA1'].skew()
# Out:
# -1.1007210311139153

# %%
df['CGPA1']=df['CGPA1'].apply(lambda x:np.log(x) if x>0 else 0)

# %%
sns.histplot(df['CGPA1'],kde=True)
plt.show()

# %%
#pr 3

# %%
df=pd.read_csv('iris.csv')

# %%
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
df=pd.read_csv('student.csv')

# %%
df.describe().T
# Out:
#                    count       mean        std  min   25%   50%   75%    max
# raisedhands        475.0  46.751579  30.876462  0.0  15.0  50.0  75.0  100.0
# VisITedResources   480.0  54.797917  33.080007  0.0  20.0  65.0  84.0   99.0
# AnnouncementsView  480.0  37.918750  26.611244  0.0  14.0  33.0  58.0   98.0
# Discussion         480.0  43.283333  27.637735  1.0  20.0  39.0  70.0   99.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 480 entries, 0 to 479
# Data columns (total 17 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   gender                    480 non-null    object
#  1   NationalITy               480 non-null    object
#  2   PlaceofBirth              477 non-null    object
#  3   StageID                   480 non-null    object
#  4   GradeID                   480 non-null    object
#  5   SectionID                 480 non-null    object
#  6   Topic                     475 non-null    object
#  7   Semester                  480 non-null    object
#  8   Relation                  480 non-null    object
#  9   raisedhands               475 non-null    float64
#  10  VisITedResources          480 non-null    int64
#  11  AnnouncementsView         480 non-null    int64
#  12  Discussion                480 non-null    int64
# ...

# %%
df.shape
# Out:
# (480, 17)

# %%
print(df['gender'].groupby(df['gender']).describe())
# Out:
#        count unique top freq
# gender
# F        175      1   F  175
# M        305      1   M  305

# %%
df['PlaceofBirth']
# Out:
# 0      KuwaIT
# 1      KuwaIT
# 2      KuwaIT
# 3      KuwaIT
# 4         NaN
#         ...
# 475    Jordan
# 476    Jordan
# 477    Jordan
# 478    Jordan
# 479    Jordan
# Name: PlaceofBirth, Length: 480, dtype: object

# %%
jdf=df[(df['PlaceofBirth']=='Jordan')]

# %%
jdf
# Out:
#     gender NationalITy PlaceofBirth       StageID GradeID SectionID  \
# 60       F      Jordan       Jordan    lowerlevel    G-05         A
# 69       M      Jordan       Jordan  MiddleSchool    G-07         A
# 70       M      Jordan       Jordan  MiddleSchool    G-07         A
# 75       M      Jordan       Jordan  MiddleSchool    G-07         A
# 110      F      Jordan       Jordan    lowerlevel    G-02         B
# ..     ...         ...          ...           ...     ...       ...
# 475      F      Jordan       Jordan  MiddleSchool    G-08         A
# 476      F      Jordan       Jordan  MiddleSchool    G-08         A
# 477      F      Jordan       Jordan  MiddleSchool    G-08         A
# 478      F      Jordan       Jordan  MiddleSchool    G-08         A
# 479      F      Jordan       Jordan  MiddleSchool    G-08         A
#
#          Topic Semester Relation  raisedhands  VisITedResources  \
# 60     English        F      Mum         21.0                10
# ...

# %%
itdf=df[df['Topic']=='IT']

# %%
itdf.head()
# Out:
#   gender NationalITy PlaceofBirth     StageID GradeID SectionID Topic  \
# 0      M          KW       KuwaIT  lowerlevel    G-04         A    IT
# 1      M          KW       KuwaIT  lowerlevel    G-04         A    IT
# 2      M          KW       KuwaIT  lowerlevel    G-04         A    IT
# 3      M          KW       KuwaIT  lowerlevel    G-04         A    IT
# 4      M          KW          NaN  lowerlevel    G-04         A    IT
#
#   Semester Relation  raisedhands  VisITedResources  AnnouncementsView  \
# 0        F   Father         15.0                16                  2
# 1        F   Father          NaN                20                  3
# 2        F   Father         10.0                 7                  0
# 3        F   Father         30.0                25                  5
# 4        F   Father         40.0                50                 12
#
#    Discussion ParentAnsweringSurvey ParentschoolSatisfaction  \
# ...

# %%
itdf.sample(10)
# Out:
#     gender NationalITy PlaceofBirth       StageID GradeID SectionID Topic  \
# 9        F          KW       KuwaIT  MiddleSchool    G-07         B    IT
# 82       M          KW       KuwaIT    lowerlevel    G-02         B    IT
# 110      F      Jordan       Jordan    lowerlevel    G-02         B    IT
# 104      M          KW       KuwaIT    lowerlevel    G-02         B    IT
# 128      M          KW       KuwaIT    lowerlevel    G-02         C    IT
# 133      M          KW       KuwaIT    lowerlevel    G-02         A    IT
# 44       F          KW       KuwaIT    HighSchool    G-09         A    IT
# 120      M          KW       KuwaIT    lowerlevel    G-02         C    IT
# 40       F          KW       KuwaIT  MiddleSchool    G-07         A    IT
# 22       M          KW       KuwaIT  MiddleSchool    G-07         A    IT
#
#     Semester Relation  raisedhands  VisITedResources  AnnouncementsView  \
# 9          F   Father         70.0                80                 25
# ...

# %%
itdf.describe(include='int64').T
# Out:
#                    count       mean        std  min   25%   50%   75%   max
# VisITedResources    95.0  35.463158  31.439510  0.0   8.0  25.0  64.5  98.0
# AnnouncementsView   95.0  18.547368  19.021694  0.0   3.0  10.0  32.5  83.0
# Discussion          95.0  42.421053  27.974372  2.0  16.0  40.0  69.5  99.0

# %%
itdf.dtypes
# Out:
# gender                       object
# NationalITy                  object
# PlaceofBirth                 object
# StageID                      object
# GradeID                      object
# SectionID                    object
# Topic                        object
# Semester                     object
# Relation                     object
# raisedhands                 float64
# VisITedResources              int64
# AnnouncementsView             int64
# Discussion                    int64
# ParentAnsweringSurvey        object
# ParentschoolSatisfaction     object
# StudentAbsenceDays           object
# Class                        object
# dtype: object

# %%
print(df['PlaceofBirth'].groupby(df['gender']).describe().T)
# Out:
# gender       F       M
# count      174     303
# unique      12      14
# top     Jordan  KuwaIT
# freq        77     125

# %%
print(df['StageID'].groupby(df['gender']).describe().T)
# Out:
# gender             F             M
# count            175           305
# unique             3             3
# top     MiddleSchool  MiddleSchool
# freq              82           166

# %%
df=pd.read_csv('iris.csv')

# %%
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
df['species'].unique()
# Out:
# array(['setosa', 'versicolor', 'virginica'], dtype=object)

# %%
sdf=df[df['species']=='setosa']
sdf.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
ver=df[df['species']=='versicolor']
ver
# Out:
#     sepal_length  sepal_width  petal_length  petal_width     species
# 50           7.0          3.2           4.7          1.4  versicolor
# 51           6.4          3.2           4.5          1.5  versicolor
# 52           6.9          3.1           4.9          1.5  versicolor
# 53           5.5          2.3           4.0          1.3  versicolor
# 54           6.5          2.8           4.6          1.5  versicolor
# 55           5.7          2.8           4.5          1.3  versicolor
# 56           6.3          3.3           4.7          1.6  versicolor
# 57           4.9          2.4           3.3          1.0  versicolor
# 58           6.6          2.9           4.6          1.3  versicolor
# 59           5.2          2.7           3.9          1.4  versicolor
# 60           5.0          2.0           3.5          1.0  versicolor
# 61           5.9          3.0           4.2          1.5  versicolor
# 62           6.0          2.2           4.0          1.0  versicolor
# ...

# %%
vir=df[df['species']=='virginica']

# %%
vir.sample(10)
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 112           6.8          3.0           5.5          2.1  virginica
# 123           6.3          2.7           4.9          1.8  virginica
# 114           5.8          2.8           5.1          2.4  virginica
# 110           6.5          3.2           5.1          2.0  virginica
# 102           7.1          3.0           5.9          2.1  virginica
# 141           6.9          3.1           5.1          2.3  virginica
# 139           6.9          3.1           5.4          2.1  virginica
# 126           6.2          2.8           4.8          1.8  virginica
# 100           6.3          3.3           6.0          2.5  virginica
# 121           5.6          2.8           4.9          2.0  virginica

# %%
len(vir)
# Out:
# 50

# %%
print(sdf.describe().T)
# Out:
#               count   mean       std  min    25%  50%    75%  max
# sepal_length   50.0  5.006  0.352490  4.3  4.800  5.0  5.200  5.8
# sepal_width    50.0  3.418  0.381024  2.3  3.125  3.4  3.675  4.4
# petal_length   50.0  1.464  0.173511  1.0  1.400  1.5  1.575  1.9
# petal_width    50.0  0.244  0.107210  0.1  0.200  0.2  0.300  0.6

# %%
print(vir.describe().T)
# Out:
#               count   mean       std  min    25%   50%    75%  max
# sepal_length   50.0  6.588  0.635880  4.9  6.225  6.50  6.900  7.9
# sepal_width    50.0  2.974  0.322497  2.2  2.800  3.00  3.175  3.8
# petal_length   50.0  5.552  0.551895  4.5  5.100  5.55  5.875  6.9
# petal_width    50.0  2.026  0.274650  1.4  1.800  2.00  2.300  2.5

# %%
print(ver.describe().T)
# Out:
#               count   mean       std  min    25%   50%  75%  max
# sepal_length   50.0  5.936  0.516171  4.9  5.600  5.90  6.3  7.0
# sepal_width    50.0  2.770  0.313798  2.0  2.525  2.80  3.0  3.4
# petal_length   50.0  4.260  0.469911  3.0  4.000  4.35  4.6  5.1
# petal_width    50.0  1.326  0.197753  1.0  1.200  1.30  1.5  1.8
